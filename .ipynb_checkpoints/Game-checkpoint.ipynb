# %%
import cv2
import numpy as np
import os
import import_ipynb
import random
import cvzone
import math
from hand_Track_Module import handDetector
from PIL import ImageFont, ImageDraw, Image

cam_width, cam_height = 1280, 720 #攝像頭畫面寬&高大小設定
cap = cv2.VideoCapture(0) #攝像頭設置
cap.set(3, cam_width) #設定攝像頭畫面寬度(id為3表示寬)
cap.set(4, cam_height) #設定攝像頭畫面高度(id為4表示高)
backgroundPath = "Background/Grass Background.jpg" #存放背景圖片資料的路徑


class GameMenu:
    def __init__(self):
        self.titlePath = "Background/Title.png"
        self.imgTitle = cv2.imread(self.titlePath, cv2.IMREAD_UNCHANGED)
        self.imgTitle = cv2.resize(self.imgTitle, (0,0), None, 0.5, 0.5)
        
        
        self.startGameFontPath = "Font/王漢宗綜藝體繁.ttf"
        self.startGameText = 'Press "Enter Key" to enter the game.'
        self.endGameText = 'Press "Esc Key" to exit the game'
        self.startGameFont = ImageFont.truetype(self.startGameFontPath, 15)
        self.endGameFont = ImageFont.truetype(self.startGameFontPath, 15)
        self.endScoreFont = ImageFont.truetype(self.startGameFontPath, 25)
        self.commentFontPath = "Font/NotoSansTC[wght].ttf"
        self.commentFont = ImageFont.truetype(self.commentFontPath, 30)
        
        self.gameTitleAppear = True #(在標題畫面的時候為True，進入後遊戲為False)
        
        
        self.imgTitle_X = 0
        self.imgTitle_Y = 0
        self.startGameText_X = 0
        self.startGameText_Y = 0
        self.endGameText_X = 0
        self.endGameText_Y = 0
       
    
    #標題畫面
    def gameTitle(self, imgBackground):
        self.imgTitle_X = int((imgBackground.shape[1] - self.imgTitle.shape[1])/2)
        self.imgTitle_Y = int((imgBackground.shape[0] - self.imgTitle.shape[0])/3)
        imgBackground = cvzone.overlayPNG(imgBackground, self.imgTitle, (self.imgTitle_X, self.imgTitle_Y))
        
        self.startGameText_X = self.imgTitle_X - 25
        self.startGameText_Y = self.imgTitle_Y + self.imgTitle.shape[0] + 40
        self.endGameText_X = self.startGameText_X + 15
        self.endGameText_Y = self.startGameText_Y + 40
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.startGameText, fill = (0, 0, 0), font = self.startGameFont)
        draw.text((self.endGameText_X, self.endGameText_Y), self.endGameText, fill = (0, 0, 0), font = self.endGameFont)
        imgBackground = np.array(imgBackground)
        
        key = cv2.waitKey(1) #等待1毫秒接收按鍵
        if key == 13: #若按下Enter按鍵
            self.gameTitleAppear = False
        
        return imgBackground
    #評語&總分畫面
    def gameEndTitle(self, imgBackground, Score):
        imgPil = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgPil)
        if Score == 500:
            text = "你的貓貓吃得很開心(✪ω✪)"
        elif Score == -50000:
            text = "你的貓是天生的垃圾車∑(✘Д✘)"
        elif Score < 0:
            text = "你在餵什麼東西！！╰(‵□′)╯"
        draw.text((self.imgTitle_X/2, self.imgTitle_Y*2), text, fill = (0, 0, 0), font = self.commentFont)
        draw.text((self.endGameText_X, self.endGameText_Y-100), f"Total Score: {Score}", fill = (0, 0, 0), font = self.endScoreFont)
        draw.text((self.endGameText_X, self.endGameText_Y), self.endGameText, fill = (0, 0, 0), font = self.endGameFont)
        imgBackground = np.array(imgPil)
        #印總分
        
        return imgBackground
    
    
    


class CatYarnGame:
    def __init__(self):
        self.garbagePath = "assets/P_garbage.png" #垃圾圖片的路徑
        self.foodPath = "assets/P_food.png" #食物圖片的路徑
        self.catPath = "assets/P_cat.png" #貓圖片的路徑
        self.cat2Path = "assets/P_cat2.png" 
        self.cat3Path = "assets/P_cat3.png" 
        self.yarnBallPath = "assets/P_YarnBall.png" #毛球圖片的路徑
        self.yarnBall2Path = "assets/P_YarnBall2.png"
        self.yarnBall3Path = "assets/P_YarnBall3.png"
        
        self.titlePath = "Background/Title.png"
        self.imgTitle = cv2.imread(self.titlePath, cv2.IMREAD_UNCHANGED)
        self.imgTitle = cv2.resize(self.imgTitle, (0,0), None, 0.5, 0.5)
        
        self.startGameFontPath = "Font/王漢宗綜藝體繁.ttf"
        self.catSelectText = 'Press 1,2,3 to select your cat'
        self.cat1Text='1.貓'
        self.cat2Text='2.貓頭鷹'
        self.cat3Text='3.貓王'
        self.ballSelectText = 'Press 1,2,3 to select your line'
        self.ball1Text='1.毛線球'
        self.ball2Text='2.中國結'
        self.ball3Text='3.義大利麵'
        self.startGameFont = ImageFont.truetype(self.startGameFontPath, 15)
        self.endGameFont = ImageFont.truetype(self.startGameFontPath, 15)
        self.endScoreFont = ImageFont.truetype(self.startGameFontPath, 25)
        self.commentFontPath = "Font/NotoSansTC[wght].ttf"
        self.commentFont = ImageFont.truetype(self.commentFontPath, 30)
        
        self.limitMin_x = 0 
        self.limitMin_y = 0
        self.limitMax_x = 0 
        self.limitMax_y = 0
        
        self.imgTitle_X = 0
        self.imgTitle_Y = 0
        self.startGameText_X = 0
        self.startGameText_Y = 0
        self.endGameText_X = 0
        self.endGameText_Y = 0

        self.imgGarbage = cv2.imread(self.garbagePath, cv2.IMREAD_UNCHANGED) #讀取垃圾圖片
        self.imgGarbage = cv2.resize(self.imgGarbage, (0,0), None, 0.25, 0.25) #設定垃圾圖片大小
        self.imgFood = cv2.imread(self.foodPath, cv2.IMREAD_UNCHANGED) #讀取食物圖片
        self.imgFood = cv2.resize(self.imgFood, (0,0), None, 0.25, 0.25) #設定食物圖片大小
        self.imgCat = cv2.imread(self.catPath, cv2.IMREAD_UNCHANGED) #讀取貓圖片
        self.imgCat = cv2.resize(self.imgCat, (0,0), None, 0.25, 0.25) #設定貓圖片大小
        self.imgCat2 = cv2.imread(self.cat2Path, cv2.IMREAD_UNCHANGED) #讀取貓2圖片
        self.imgCat2 = cv2.resize(self.imgCat2, (0,0), None, 0.25, 0.25) #設定貓2圖片大小
        self.imgCat3 = cv2.imread(self.cat3Path, cv2.IMREAD_UNCHANGED) #讀取貓3圖片
        self.imgCat3 = cv2.resize(self.imgCat3, (0,0), None, 0.25, 0.25) #設定貓3圖片大小
        self.imgYarnBall = cv2.imread(self.yarnBallPath, cv2.IMREAD_UNCHANGED) #讀取毛球圖片
        self.imgYarnBall = cv2.resize(self.imgYarnBall, (0,0), None, 0.1, 0.1) #設定毛球圖片大小
        self.imgYarnBall2 = cv2.imread(self.yarnBall2Path, cv2.IMREAD_UNCHANGED) #讀取毛球2圖片
        self.imgYarnBall2 = cv2.resize(self.imgYarnBall2, (0,0), None, 0.1, 0.1) #設定毛球2圖片大小
        self.imgYarnBall3 = cv2.imread(self.yarnBall3Path, cv2.IMREAD_UNCHANGED) #讀取毛球3圖片
        self.imgYarnBall3 = cv2.resize(self.imgYarnBall3, (0,0), None, 0.1, 0.1) #設定毛球3圖片大小
        
        self.imgCat_X = 0
        self.imgCat_Y = 0
        
        self.imgCat2_X = 0
        self.imgCat2_Y = 0
        
        self.imgCat3_X = 0
        self.imgCat3_Y = 0
        
        self.imgYarnBall_X = 0
        self.imgYarnBall_Y = 0
        
        self.imgYarnBall2_X = 0
        self.imgYarnBall2_Y = 0
        
        self.imgYarnBall3_X = 0
        self.imgYarnBall3_Y = 0
        
        self.catSelect=True
        self.ballSelect=True
        
        self.catType=0
        self.ballType=0
        
        self.garbage = [] #垃圾位置存取陣列
        self.garbageCount = 0 #垃圾總計數量
        self.minGarbageCount = 5 #垃圾生成隨機數量最小範圍
        self.maxGarbageCount = 15 #垃圾生成隨機數量最大範圍
        self.food = [] #食物位置存取陣列
        self.cat = 5,5 #貓的位置(起始位置)
        self.yarnBall = 50,50 #毛球的位置(起始位置)

        self.pull = False #拉物件回起點的狀態(游標碰到物件後變為True，物件拉回起點後變為False)
        self.gameset = False #遊戲準備的狀態(食物&垃圾物件生成完畢後變為True，物件拉回起點後變為False)
        self.gamestart = False #遊戲開始的狀態(當游標移到起始位置變為True，游標碰到物件後變為False)
        
        self.touchGarbage = [] #紀錄抓到的垃圾座標(垃圾拉回起點後清空)
        self.touchFood = [] #紀錄抓到的食物座標(食物拉回起點後清空)
        
        self.points = [] #紀錄路線的節點
        self.previousPoint = 0,0 #路線目前節點的上一個節點
        
        self.TotalScore = 0  #分數
        
        self.gameRound = 0
        self.gameRoundEnd = 5
        
        self.font = cv2.FONT_HERSHEY_SIMPLEX
        self.font_scale = 0.5
        self.font_thickness = 1
        self.start_text = "Please place the cursor on the yarn ball to start the game"


    #攝像頭出現遊玩畫面
    def webcamPlayArea(self, gameSize_x, gameSize_y):
        offset_x, offset_y = int((cam_width - gameSize_x) / 2), int((cam_height - gameSize_y) / 2)
        self.limitMin_x, self.limitMin_y = offset_x, offset_y
        self.limitMax_x, self.limitMax_y = cam_width-offset_x, cam_height-offset_y 
        cv2.rectangle(img, (self.limitMin_x, self.limitMin_y), (self.limitMax_x, self.limitMax_y), (255,0,0), 2)  
    
    
    #隨著回合推進，可能生成的垃圾數量越多
    def roundChangeAddGarbageCount(self):
        self.gameRound += 1
        if self.gameRound > 1:
            self.minGarbageCount += 5
            self.maxGarbageCount += 5
        if self.gameRound <= self.gameRoundEnd:
            self.garbageCount = random.randint(self.minGarbageCount, self.maxGarbageCount)
            
    def gameCatSelect(self, imgBackground):
        self.imgCat_X = 128
        self.imgCat_Y = int((imgBackground.shape[0] - self.imgTitle.shape[0])/3)
        imgBackground = cvzone.overlayPNG(imgBackground, self.imgCat, (self.imgCat_X, self.imgCat_Y))
        self.startGameText_X = self.imgCat_X +15
        self.startGameText_Y = self.imgCat_Y +80
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.cat1Text, fill = (0, 0, 0), font = self.startGameFont)
        imgBackground = np.array(imgBackground)
        
        self.imgCat2_X = 230
        self.imgCat2_Y = int((imgBackground.shape[0] - self.imgTitle.shape[0])/3) -10
        imgBackground = cvzone.overlayPNG(imgBackground, self.imgCat2, (self.imgCat2_X, self.imgCat2_Y))
        self.startGameText_X = self.imgCat2_X +20
        self.startGameText_Y = self.imgCat2_Y +90
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.cat2Text, fill = (0, 0, 0), font = self.startGameFont)
        imgBackground = np.array(imgBackground)
        
        self.imgCat3_X = 384
        self.imgCat3_Y = int((imgBackground.shape[0] - self.imgTitle.shape[0])/3)
        imgBackground = cvzone.overlayPNG(imgBackground, self.imgCat3, (self.imgCat3_X, self.imgCat3_Y))
        self.startGameText_X = self.imgCat3_X +15
        self.startGameText_Y = self.imgCat3_Y +80
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.cat3Text, fill = (0, 0, 0), font = self.startGameFont)
        imgBackground = np.array(imgBackground)
        
        self.startGameText_X = self.imgTitle_X + 125
        self.startGameText_Y = self.imgTitle_Y + self.imgTitle.shape[0] + 130
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.catSelectText, fill = (0, 0, 0), font = self.startGameFont)
        imgBackground = np.array(imgBackground)
        
        
        key = cv2.waitKey(1) #等待1毫秒接收按鍵
        if key == 49: #若按下Enter按鍵
            self.catType=1
            self.catSelect = False
        elif key == 50: #若按下Enter按鍵
            self.catType=2
            self.catSelect = False
        elif key == 51: #若按下Enter按鍵
            self.catType=3
            self.catSelect = False
        
        
        return imgBackground
            
    def gameBallSelect(self, imgBackground):
        
        self.imgYarnBall_X = 128
        self.imgYarnBall_Y = int((imgBackground.shape[0] - self.imgTitle.shape[0])/3)
        imgBackground = cvzone.overlayPNG(imgBackground, self.imgYarnBall, (self.imgYarnBall_X, self.imgYarnBall_Y))
        self.startGameText_X = self.imgYarnBall_X -5
        self.startGameText_Y = self.imgYarnBall_Y +60
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.ball1Text, fill = (0, 0, 0), font = self.startGameFont)
        imgBackground = np.array(imgBackground)
        
        self.imgYarnBall2_X = 256
        self.imgYarnBall2_Y = int((imgBackground.shape[0] - self.imgTitle.shape[0])/3)
        imgBackground = cvzone.overlayPNG(imgBackground, self.imgYarnBall2, (self.imgYarnBall2_X, self.imgYarnBall2_Y))
        self.startGameText_X = self.imgYarnBall2_X -5
        self.startGameText_Y = self.imgYarnBall2_Y +60
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.ball2Text, fill = (0, 0, 0), font = self.startGameFont)
        imgBackground = np.array(imgBackground)
        
        self.imgYarnBall3_X = 384
        self.imgYarnBall3_Y = int((imgBackground.shape[0] - self.imgTitle.shape[0])/3)
        imgBackground = cvzone.overlayPNG(imgBackground, self.imgYarnBall3, (self.imgYarnBall3_X, self.imgYarnBall3_Y))
        self.startGameText_X = self.imgYarnBall3_X -5
        self.startGameText_Y = self.imgYarnBall3_Y +60
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.ball3Text, fill = (0, 0, 0), font = self.startGameFont)
        imgBackground = np.array(imgBackground)
        
        self.startGameText_X = self.imgTitle_X + 125
        self.startGameText_Y = self.imgTitle_Y + self.imgTitle.shape[0] + 130
        imgBackground = Image.fromarray(imgBackground)
        draw = ImageDraw.Draw(imgBackground)
        draw.text((self.startGameText_X, self.startGameText_Y), self.ballSelectText, fill = (0, 0, 0), font = self.endGameFont)
        imgBackground = np.array(imgBackground)
        
        key = cv2.waitKey(1) #等待1毫秒接收按鍵
        if key == 49: #若按下Enter按鍵
            self.ballType=1
            self.ballSelect = False
        elif key == 50: #若按下Enter按鍵
            self.ballType=2
            self.ballSelect = False
        elif key == 51: #若按下Enter按鍵
            self.ballType=3
            self.ballSelect = False
        
        return imgBackground
    
    
    
    
    #垃圾&食物的座標生成
    def objectsCoordinates(self):
        overlap = 0
        self.garbage = [] #所有垃圾的座標位置清空
        for i in range(self.garbageCount):
            x = random.randint(100, 540)
            y = random.randint(50, 290)
            self.garbage.append([i,x,y]) 
            
        while overlap == 0:
            x = random.randint(200, 540)
            y = random.randint(100, 290)
            overlap = 1
            self.food = [x,y]
            for i in range(self.garbageCount):
                if x == self.garbage[i][1]:
                    if y == self.garbage[i][2]:
                        overlap = 0
        self.gameset = True  
        
        
    #畫線
    def drawLine(self, imgBackground, currentPoint):
        px, py = self.previousPoint #紀錄上一個節點位置
        cx, cy = currentPoint #紀錄目前的節點位置
        self.points.append([cx, cy])
        self.previousPoint = cx, cy
        
        for index, point in enumerate(self.points):
            if index != 0:
                cv2.line(imgBackground, self.points[index - 1], self.points[index], (0, 0, 255), 5)
        
        return imgBackground
    
    
    #拉物件到起點
    def pullObject(self, imgBackground):
        totalIndex = len(self.points) - 1
        for index in range(totalIndex, 0, -1):
            cv2.line(imgBackground, self.points[index], self.points[index - 1], (0, 0, 255), 5)
            
        if self.touchFood != []:
            self.touchFood = self.points[totalIndex]
        elif self.touchGarbage != []:
            self.touchGarbage[1] = self.points[totalIndex][0]
            self.touchGarbage[2] = self.points[totalIndex][1]
            
        self.points.pop(totalIndex)
        
        if self.points == []:
            self.updateScore()  # 更新分數
            self.gameset = False
            self.pull = False
            self.touchFood = []
            self.touchGarbage = []
        return imgBackground
    
    
    #偵測碰撞
    def detectCollision(self, gamePoint):
        if self.pull == False:
            if gamePoint[0] >= self.yarnBall[0] and gamePoint[0] <= self.yarnBall[0] + self.imgYarnBall.shape[1]:
                if gamePoint[1] >= self.yarnBall[1] and gamePoint[1] <= self.yarnBall[1] + self.imgYarnBall.shape[0]:
                    self.gamestart = True
        if self.gamestart == True:
            for i in range(self.garbageCount):
                if gamePoint[0] >= (self.garbage[i][1]) and gamePoint[0] <= (self.garbage[i][1]) + self.imgGarbage.shape[1]:
                    if gamePoint[1] >= (self.garbage[i][2]) and gamePoint[1] <= (self.garbage[i][2]) + self.imgGarbage.shape[0]:
                        self.gamestart = False
                        self.pull = True
                        self.touchGarbage = self.garbage[i]
            
            if gamePoint[0] >= (self.food[0]) and gamePoint[0] <= (self.food[0]) + self.imgFood.shape[1]:
                if gamePoint[1] >= (self.food[1]) and gamePoint[1] <= (self.food[1]) + self.imgFood.shape[0]:
                    self.gamestart = False
                    self.pull = True
                    self.touchFood = self.food
    
    
    #更新分數
    def updateScore(self):
        if self.touchFood:
            self.TotalScore += 100 #碰到食物+100
        elif self.touchGarbage:
            self.TotalScore -= 10000 #碰到垃圾+10000
                        
                
    #物件出現在遊戲畫面
    def objectsAppear(self, imgBackground):
        global backgroundPath
        if self.catType==1:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgCat, (self.cat[0], self.cat[1]))
        elif self.catType==2:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgCat2, (self.cat[0], self.cat[1]))
        elif self.catType==3:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgCat3, (self.cat[0], self.cat[1]))
        if self.ballType==1:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgYarnBall, (self.yarnBall[0], self.yarnBall[1]))
        elif self.ballType==2:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgYarnBall2, (self.yarnBall[0], self.yarnBall[1]))
        elif self.ballType==3:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgYarnBall3, (self.yarnBall[0], self.yarnBall[1]))
        
        if self.touchFood == []:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgFood, (self.food[0], self.food[1]))
        elif self.touchFood != []:
            imgBackground = cvzone.overlayPNG(imgBackground, self.imgFood, (self.touchFood[0], self.touchFood[1]))
            
        if self.touchGarbage == []:
            for i in range(self.garbageCount):
                imgBackground = cvzone.overlayPNG(imgBackground, self.imgGarbage, (self.garbage[i][1], self.garbage[i][2]))
        elif self.touchGarbage != []:
            for i in range(self.garbageCount):
                if i == self.touchGarbage[0]:
                    imgBackground = cvzone.overlayPNG(imgBackground, self.imgGarbage, (self.touchGarbage[1], self.touchGarbage[2]))
                    continue
                imgBackground = cvzone.overlayPNG(imgBackground, self.imgGarbage, (self.garbage[i][1], self.garbage[i][2]))
            
        return imgBackground

    
    #改變遊戲畫面特效與顯示遊戲的提示文字
    def putTextAndChangeBackground(self, imgBackground):
        global backgroundPath
        #第三回合開始，背景換成紅色
        if self.gameRound == 3:
            backgroundPath = "Background/Red.jpg"
        
        #第四回合開始，畫面呈現模糊(可選)狀態
        if self.gameRound == 4:
            backgroundPath = "Background/Grass Background.jpg"
            imgBackground = cv2.GaussianBlur(imgBackground, (81, 81),0)
            
        #第五回合開始，畫面呈現模糊(可選)狀態
        if self.gameRound == 5:
            backgroundPath = "Background/Red.jpg"
            imgBackground = cv2.GaussianBlur(imgBackground, (81, 81),0)
            
        if self.gameRound <= self.gameRoundEnd:
            # 在貓咪底下顯示分數&目前回合數
            cv2.putText(imgBackground, f"Score: {self.TotalScore}", (self.cat[0], self.cat[1] + self.imgCat.shape[0] + 20),
                        cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(imgBackground, f"Round {self.gameRound}", (self.cat[0], self.cat[1] + self.imgCat.shape[0] + 40),
                        cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            
        if self.pull == False and self.gamestart == False:
            cv2.putText(imgBackground, self.start_text, (50, 190),
                        self.font, self.font_scale, (0, 0, 0), self.font_thickness, cv2.LINE_AA)
        
        return imgBackground
    

#主程式
detector = handDetector() #建立偵測class
gameMenu = GameMenu() #建立標題畫面class
game = CatYarnGame() #建立遊戲class

while True:
    #第一步驟：攝像頭基本設定
    retval, img = cap.read() #讀取攝像頭照到的影像，retval表示影像捕獲成功or失敗
    img = detector.findHands(img) #偵測手掌
    landmarkList = detector.findPosition(img, 0) #獲取手掌偵測節點資料
    img = np.flip(img, axis=1) #攝像頭畫面左右翻轉(axis=1表示左右翻轉，axis=0表示上下翻轉)
    img = np.ascontiguousarray(img)
    imgBackground = cv2.imread(backgroundPath)
    
    
    #第二步驟：繪製遊玩範圍於攝像頭視窗
    gameSize_x, gameSize_y = imgBackground.shape[1], imgBackground.shape[0] #獲取背景圖片大小(作為遊玩畫面大小)
    game.webcamPlayArea(gameSize_x, gameSize_y) #攝像頭繪製遊玩範圍
    
    
    #第三步驟：偵測手部
    if len(landmarkList) != 0: #如果有偵測到手部的時候
        finger_x, finger_y = -(landmarkList[8][1] - cam_width), landmarkList[8][2] #獲取攝像頭的食指座標
        gamePoint = (finger_x - game.limitMin_x, finger_y - game.limitMin_y) #將攝像頭的食指座標轉換為遊戲座標

        if finger_x > game.limitMin_x and finger_x < game.limitMax_x and finger_y > game.limitMin_y and finger_y < game.limitMax_y: #若食指座標有在遊戲範圍內
            cv2.circle(imgBackground, gamePoint, 5, (0, 0, 255), cv2.FILLED) #在遊戲畫面顯示座標
            
        #難度測試 backgroundPath = "Background/Red.jpg"
    
    
    if gameMenu.gameTitleAppear == True:
        #第四(A)步驟：出現標題畫面
        imgBackground = gameMenu.gameTitle(imgBackground)
    
    elif game.catSelect==True:
        imgBackground = game.gameCatSelect(imgBackground)
        
    elif game.ballSelect==True:
        imgBackground = game.gameBallSelect(imgBackground)
        
    elif gameMenu.gameTitleAppear == False and  game.gameRound < game.gameRoundEnd + 1:
        #第四(B)步驟：遊戲進行
        if game.gameset == False:
            game.roundChangeAddGarbageCount() #隨著回合推進變化遊戲內容
            game.objectsCoordinates() #生成物件座標並改變遊戲準備狀態

        if game.gamestart == True:
            imgBackground = game.drawLine(imgBackground, gamePoint) #開始畫線

        if len(landmarkList) != 0: #如果有偵測到手部的時候
            game.detectCollision(gamePoint) #偵測物體碰撞，並改變遊戲開始&準備的狀態

        if game.pull == True:
            imgBackground = game.pullObject(imgBackground) #拉物件回毛線球(起點)   

        imgBackground = game.objectsAppear(imgBackground) #所有遊戲物件的產生
        imgBackground = game.putTextAndChangeBackground(imgBackground)
        
        
    elif game.gameRound == game.gameRoundEnd + 1:
        #第四(C)步驟：出現遊戲結束畫面&背景變回初始狀態
        backgroundPath = "Background/Grass Background.jpg"
        imgBackground = gameMenu.gameEndTitle(imgBackground, game.TotalScore)
        
    
    #第五步驟：視窗的產生&即時更新
    cv2.namedWindow("Image", cv2.WINDOW_NORMAL) #新增攝像頭視窗(Image)，允許視窗自由縮放
    cv2.resizeWindow("Image", img.shape[1]//2, img.shape[0]//2) #改變"Image"視窗大小
    cv2.imshow("Image", img) #攝像頭照到的影像顯示到"Image"視窗
    
    cv2.namedWindow("Game", cv2.WINDOW_NORMAL) #新增遊戲視窗(Game)，允許視窗自由縮放
    cv2.resizeWindow("Game", imgBackground.shape[1]*2, imgBackground.shape[0]*2) #改變"Game"視窗大小
    cv2.imshow("Game", imgBackground) #將背景圖片顯示到"Game"視窗
    
    
    #第六步驟：退出偵測
    key = cv2.waitKey(1) #等待1毫秒接收按鍵
    if key == 27: #若按下Esc按鍵
        break
        
cap.release() #結束攝像機
cv2.destroyAllWindows() #關閉所有視窗
# Out:
# importing Jupyter notebook from hand_Track_Module.ipynb
